# %%
# imports and configuration
import pandas as pd
import requests
import time
from pathlib import Path

# %% [markdown]
# ## Functions

# %%
def load_tournament_results(filepath):
    tournament_results = pd.read_csv(filepath)
    print(f"loaded {len(tournament_results):,} records")
    print(f"unique cards: {tournament_results['card_name'].nunique():,}")
    return tournament_results

def drop_unneeded_columns(df):
    drop_columns = ["source_file", 'record', 'player', 'player_wins' ,'player_losses', 'tournament_size_bucket'] #we ended up not using buckets
    df = df.drop(columns=drop_columns)
    return df

def drop_basic_land_rows(df):
    basic_lands = [
        'Plains', 'Island', 'Swamp', 'Mountain', 'Forest', 'Wastes',
        'Snow-Covered Plains', 'Snow-Covered Island', 'Snow-Covered Swamp', 
        'Snow-Covered Mountain', 'Snow-Covered Forest', 'Snow-Covered Wastes' #snow-covered wastes didn't exist at the time but just in case
    ]
    df = df[~df["card_name"].isin(basic_lands)]
    return df

### Card score calculations ###
def calc_card_copy_score(df):
    # apply mainboard/sideboard weight to each copy
    df["card_copy_score"] = df.apply(
        lambda row: row["card_count"] * mainboard_weight if row["is_mainboard"]
        else row["card_count"] * sideboard_weight, axis=1
    )

    # sum weighted copies per card per player per tournament
    deck_scores = df.groupby(
        ["card_name", "player", "source_file"]
    )["card_copy_score"].sum().reset_index()
    #deck_scores.columns = ["card_name", "player", "source_file", "deck_copy_score"]
    max_possible_card_score = max_card_copies * mainboard_weight # this = 4 in our model
    deck_scores["card_copy_score"] = deck_scores["card_copy_score"] / max_possible_card_score
    return deck_scores
    
def calc_win_rate_score(df):
    # this metric is already calculated out of 1 so we don't need to do further work as we drop any results with a less than 75% performance
    df['win_rate_score'] = df['win_rate'].round(4)
    return df


################
### Card weight calculations ###
def explore_tournament_size_buckets(tournament_results):
    bucket_counts = tournament_results.groupby("tournament_size_bucket")["source_file"].nunique()
    bucket_records = tournament_results.groupby("tournament_size_bucket")["card_name"].count()
    summary = pd.DataFrame({
        "tournaments": bucket_counts,
        "records": bucket_records
    })
    summary["pct_tournaments"] = (summary["tournaments"] / summary["tournaments"].sum() * 100).round(1)
    summary["pct_records"] = (summary["records"] / summary["records"].sum() * 100).round(1)
    print(summary.to_string())

def apply_tournament_size_weights(tournament_results, tournament_size_weights):
    tournament_results["tournament_size_weight"] = tournament_results["tournament_size_bucket"].apply(#return the value associated with the key that matches the tournament size
        lambda x: tournament_size_weights[x]
    )
    tournament_results["weighted_copies"] = tournament_results["weighted_copies"] * tournament_results["tournament_size_weight"]
    # print("applied size weights:")
    for bucket, weight in tournament_size_weights.items():
        count = (tournament_results["tournament_size_bucket"] == bucket).sum()
        #print(f"  {bucket}: {weight} ({count:,} records)")
    return tournament_results

def aggregate_raw_performance(tournament_results):
    card_performance = tournament_results.groupby("card_name").agg(
        total_weighted_copies=("weighted_copies", "sum"),
        deck_appearances=("player", "count"),
        avg_weighted_copies_per_deck=("weighted_copies", "mean"),
        avg_win_rate=("win_rate", "mean"),
    ).reset_index()
    card_performance["avg_weighted_copies_per_deck"] = card_performance["avg_weighted_copies_per_deck"].round(2)
    card_performance["avg_win_rate"] = card_performance["avg_win_rate"].round(2)

    #print(f"aggregated {len(card_performance):,} unique cards")
    return card_performance

def calculate_card_scores(card_performance):
    card_performance["performance_score"] = card_performance["total_weighted_copies"] * card_performance["avg_win_rate"]
    card_scores = card_performance.sort_values("performance_score", ascending=False).reset_index(drop=True)
    #print(f"calculated scores for {len(card_scores):,} unique cards")
    return card_scores

### Misc ###
def show_cards(df, card_names):
    mask = df["card_name"].isin(card_names)
    return(df[mask].to_string(index=False))

# %% [markdown]
# ## Code

# %% [markdown]
# ### Universal Variables

# %%
data_dir = Path("C:/Users/david/Documents/GitHub/ai_projects/modern_cube/data")
filtered_data = data_dir / "processed/filtered_card_records_2016_2018.csv"
output_dir = data_dir / "processed"

# cube configuration
cube_size = 360

# weights for metrics
#As we do not have a way to know how often a sideboard card is used we have to guestimate
mainboard_weight = 1
sideboard_weight = .5
max_card_copies = 4 # max played in Modern (we omit basic lands)

# metric weights (must sum to 1.0)
metric_weights = {
    "card_copy_weight": 0.2,
    "win_rate_weight": 0.2,
    "tournament_size_weight": 0.2,
    "tournament_consistency_weight": 0.2,
    "legal_window_weight": 0.2
}

# data window
data_start = "2016-01-01"
data_end = "2018-12-31"

# %% [markdown]
# ### Executed Code

# %%
tournament_results = load_tournament_results(filtered_data)
#tournament_results = drop_unneeded_columns(tournament_results)
tournament_results = drop_basic_land_rows(tournament_results)


#tournament_results = calc_card_copy_score(tournament_results)
#tournament_results = calc_win_rate_score(tournament_results)
print(len(tournament_results))
tournament_results.head()
# Out:
# loaded 118,070 records
# unique cards: 1,633
# 110862
#                  card_name  card_count  is_mainboard         player  \
# 0        Ancient Stirrings           4          True  BoozeMongoose
# 1         Chromatic Sphere           4          True  BoozeMongoose
# 2           Chromatic Star           4          True  BoozeMongoose
# 3  Emrakul, the Aeons Torn           1          True  BoozeMongoose
# 4           Expedition Map           4          True  BoozeMongoose
#
#    player_wins  player_losses     tournament_name       tournament_date  \
# 0            4              0  Modern Daily Swiss  2016-01-01T00:00:00Z
# 1            4              0  Modern Daily Swiss  2016-01-01T00:00:00Z
# 2            4              0  Modern Daily Swiss  2016-01-01T00:00:00Z
# 3            4              0  Modern Daily Swiss  2016-01-01T00:00:00Z
# 4            4              0  Modern Daily Swiss  2016-01-01T00:00:00Z
#
#                                  source_file  tournament_size record  \
# 0  modern-daily-swiss-2016-01-019177191.json               24    4-0
# 1  modern-daily-swiss-2016-01-019177191.json               24    4-0
# 2  modern-daily-swiss-2016-01-019177191.json               24    4-0
# 3  modern-daily-swiss-2016-01-019177191.json               24    4-0
# 4  modern-daily-swiss-2016-01-019177191.json               24    4-0
#
#    win_rate tournament_size_bucket
# 0       1.0                  small
# 1       1.0                  small
# 2       1.0                  small
# 3       1.0                  small
# 4       1.0                  small

# %%
def calc_card_copy_score(df):
    # apply mainboard/sideboard weight to each copy
    df["card_copy_score"] = df.apply(
        lambda row: row["card_count"] * mainboard_weight if row["is_mainboard"]
        else row["card_count"] * sideboard_weight, axis=1
    )

    # sum weighted copies per card per player per tournament
    deck_scores = df.groupby(
        ["card_name", "player", "source_file"]
    )["card_copy_score"].sum().reset_index()
    #deck_scores.columns = ["card_name", "player", "source_file", "deck_copy_score"]
    max_possible_card_score = max_card_copies * mainboard_weight # this = 4 in our model
    deck_scores["card_copy_score"] = deck_scores["card_copy_score"] / max_possible_card_score
    return deck_scores

x = calc_card_copy_score(tournament_results)
x
# Out:
#                   card_name           player  \
# 0       Abbot of Keral Keep   43percentturnt
# 1       Abbot of Keral Keep        Cloudform
# 2       Abbot of Keral Keep         Jadecavy
# 3       Abbot of Keral Keep     MLGSKELETONS
# 4       Abbot of Keral Keep     MLGSKELETONS
# ...                     ...              ...
# 107238   Zombie Infestation  InspectorGadget
# 107239   Zombie Infestation          Zemonck
# 107240   Zulaport Cutthroat        topazcrow
# 107241    Zurgo Bellstriker         Natagiri
# 107242    Zurgo Bellstriker   thepinkdevil33
#
#                                           source_file  card_copy_score
# 0       modern-ptq-preliminary-2016-07-109881065.json            0.125
# 1           modern-daily-swiss-2016-01-179261496.json            1.000
# 2           modern-daily-swiss-2016-01-219286319.json            0.250
# 3           modern-daily-swiss-2016-03-099462663.json            0.500
# 4           modern-daily-swiss-2016-03-109485636.json            0.500
# ...                                               ...              ...
# 107238  modern-ptq-preliminary-2016-05-089667546.json            0.375
# 107239      modern-daily-swiss-2016-01-269286461.json            1.000
# 107240  modern-ptq-preliminary-2016-07-089881060.json            0.750
# 107241      modern-daily-swiss-2016-02-029313038.json            0.250
# 107242  modern-ptq-preliminary-2016-02-059339589.json            0.250
#
# [107243 rows x 4 columns]

# %%
tournament_results[tournament_results.source_file == 'modern-ptq-preliminary-2016-07-109881065.json']
# Out:
#                       card_name  card_count  is_mainboard          player  \
# 66539           Cavern of Souls           4          True        Jstimec1
# 66540          Chord of Calling           4          True        Jstimec1
# 66541         Collected Company           4          True        Jstimec1
# 66542            Dwynen's Elite           4          True        Jstimec1
# 66543          Elvish Archdruid           4          True        Jstimec1
# ...                         ...         ...           ...             ...
# 66663          Phyrexian Unlife           1         False  43percentturnt
# 66664                 Pyroclasm           1         False  43percentturnt
# 66665             Stony Silence           1         False  43percentturnt
# 66666                 Tarmogoyf           1         False  43percentturnt
# 66667  Tasigur, the Golden Fang           1         False  43percentturnt
#
#        player_wins  player_losses         tournament_name  \
# 66539            4              1  Modern PTQ Preliminary
# 66540            4              1  Modern PTQ Preliminary
# 66541            4              1  Modern PTQ Preliminary
# 66542            4              1  Modern PTQ Preliminary
# 66543            4              1  Modern PTQ Preliminary
# ...            ...            ...                     ...
# 66663            4              1  Modern PTQ Preliminary
# 66664            4              1  Modern PTQ Preliminary
# 66665            4              1  Modern PTQ Preliminary
# 66666            4              1  Modern PTQ Preliminary
# 66667            4              1  Modern PTQ Preliminary
#
#             tournament_date                                    source_file  \
# 66539  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66540  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66541  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66542  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66543  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# ...                     ...                                            ...
# 66663  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66664  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66665  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66666  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
# 66667  2016-07-10T00:00:00Z  modern-ptq-preliminary-2016-07-109881065.json
#
#        tournament_size record  win_rate tournament_size_bucket  \
# 66539               18    4-1       0.8                  small
# 66540               18    4-1       0.8                  small
# 66541               18    4-1       0.8                  small
# 66542               18    4-1       0.8                  small
# 66543               18    4-1       0.8                  small
# ...                ...    ...       ...                    ...
# 66663               18    4-1       0.8                  small
# 66664               18    4-1       0.8                  small
# 66665               18    4-1       0.8                  small
# 66666               18    4-1       0.8                  small
# 66667               18    4-1       0.8                  small
#
#        card_copy_score  win_rate_score  weighted_copy
# 66539              4.0             0.8            4.0
# 66540              4.0             0.8            4.0
# 66541              4.0             0.8            4.0
# 66542              4.0             0.8            4.0
# 66543              4.0             0.8            4.0
# ...                ...             ...            ...
# 66663              0.5             0.8            0.5
# 66664              0.5             0.8            0.5
# 66665              0.5             0.8            0.5
# 66666              0.5             0.8            0.5
# 66667              0.5             0.8            0.5
#
# [126 rows x 16 columns]

# %%
tournament_results['win_rate_score'].unique()
# Out:
# array([1.    , 0.75  , 0.8   , 0.9   , 0.7778, 0.9091, 0.8182, 0.875 ,
#        0.8889, 0.8571, 0.9167, 0.8333, 0.7692, 0.8462])

# %%
tournament_results = apply_copy_weights(tournament_results, mainboard_weight, sideboard_weight)
tournament_results = apply_tournament_size_weights(tournament_results, tournament_size_weights)
tournament_results.head()
# Out:
#                  card_name  card_count  is_mainboard     tournament_name  \
# 0        Ancient Stirrings           4          True  Modern Daily Swiss
# 1         Chromatic Sphere           4          True  Modern Daily Swiss
# 2           Chromatic Star           4          True  Modern Daily Swiss
# 3  Emrakul, the Aeons Torn           1          True  Modern Daily Swiss
# 4           Expedition Map           4          True  Modern Daily Swiss
#
#         tournament_date  tournament_size  win_rate tournament_size_bucket  \
# 0  2016-01-01T00:00:00Z               24       1.0                  small
# 1  2016-01-01T00:00:00Z               24       1.0                  small
# 2  2016-01-01T00:00:00Z               24       1.0                  small
# 3  2016-01-01T00:00:00Z               24       1.0                  small
# 4  2016-01-01T00:00:00Z               24       1.0                  small
#
#    weighted_copies  tournament_size_weight
# 0             1.00                    0.25
# 1             1.00                    0.25
# 2             1.00                    0.25
# 3             0.25                    0.25
# 4             1.00                    0.25

# %%
card_performance = aggregate_raw_performance(tournament_results)
card_scores = calculate_card_scores(card_performance)

# %%
 # TODO on scryfall get modern legal date

# %%
card_performance = aggregate_raw_performance(tournament_results)
card_performance.head()
# Out:
#              card_name  total_weighted_copies  deck_appearances  \
# 0  Abbot of Keral Keep                   22.5                10
# 1               Abrade                  100.5               104
# 2         Abrupt Decay                 1108.0               569
# 3      Abundant Growth                    7.0                 3
# 4     Abzan Ascendancy                    4.0                 1
#
#    avg_weighted_copies_per_deck  avg_win_rate
# 0                          2.25          0.80
# 1                          0.97          0.79
# 2                          1.95          0.81
# 3                          2.33          0.85
# 4                          4.00          0.80

# %%
banned_cards = ["Splinter Twin", "Summer Bloom", "Eye of Ugin", 'Gitaxian Probe', 'Golgari Grave-Troll']
show_cards(card_scores, banned_cards).head()
# Out:
#                card_name  total_weighted_copies  deck_appearances  \
# 24           Eye of Ugin                 1715.0               493
# 76        Gitaxian Probe                  971.0               252
# 319  Golgari Grave-Troll                  177.0                45
# 332         Summer Bloom                  172.0                43
# 345        Splinter Twin                  164.0                42
#
#      avg_weighted_copies_per_deck  avg_win_rate  performance_score
# 24                           3.48          0.81            1389.15
# 76                           3.85          0.82             796.22
# 319                          3.93          0.85             150.45
# 332                          4.00          0.80             137.60
# 345                          3.90          0.79             129.56

# %%
unbanned_cards = ['Ancestral Vision', 'Sword of the Meek', 'Jace, the Mind Sculptor', 'Bloodbraid Elf']
show_cards(card_scores, unbanned_cards).head()
# Out:
#                     card_name  total_weighted_copies  deck_appearances  \
# 297          Ancestral Vision                  215.0                88
# 313   Jace, the Mind Sculptor                  199.5                88
# 424            Bloodbraid Elf                  115.0                30
# 1041        Sword of the Meek                    6.0                 3
#
#       avg_weighted_copies_per_deck  avg_win_rate  performance_score
# 297                           2.44          0.80             172.00
# 313                           2.27          0.78             155.61
# 424                           3.83          0.78              89.70
# 1041                          2.00          0.80               4.80

# %%
iconic_cards = ['Dark Confidant', 'Snapcaster Mage', 'Stoneforged Mystic']
show_cards(card_scores, iconic_cards).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 iconic_cards = ['Dark Confidant', 'Snapcaster Mage', 'Stoneforged Mystic']
# ----> 2 show_cards(card_scores, iconic_cards).head()
#
# NameError: name 'card_scores' is not defined

# %%
card_scores = calculate_card_scores(card_performance)
card_scores.head()
# Out:
#           card_name  total_weighted_copies  deck_appearances  \
# 0    Lightning Bolt                 5011.0              1482
# 1            Island                 4105.5              1362
# 2     Path to Exile                 3793.0              1332
# 3          Mountain                 3496.5              1646
# 4  Wooded Foothills                 3460.5              1119
#
#    avg_weighted_copies_per_deck  avg_win_rate  performance_score
# 0                          3.38          0.81           4058.910
# 1                          3.01          0.80           3284.400
# 2                          2.85          0.81           3072.330
# 3                          2.12          0.81           2832.165
# 4                          3.09          0.81           2803.005

# %% [markdown]
# ## Apendix

# %%
# use this to determine weight of tournaments which we ended up not using in the model
explore_tournament_size_buckets(tournament_results)

#this is based on distribution of tournaments in the data which can be seen in the apendix
tournament_size_weights = {
    "small": 0.25,
    "medium": 1.0,
    "large": 2.0,
    "major": 4.0
}
# Out:
#                         tournaments  records  pct_tournaments  pct_records
# tournament_size_bucket
# large                           106    28197             22.2         23.9
# major                            23    16312              4.8         13.8
# medium                          142    36594             29.7         31.0
# small                           207    36967             43.3         31.3
